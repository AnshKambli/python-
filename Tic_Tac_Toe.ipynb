# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshKambli/python-/blob/main/Tic_Tac_Toe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def print_board(board):
    """Display the current state of the board."""
    for row in board:
        print(" | ".join(row))
        print("-" * 9)

def check_winner(board):
    """Check if there's a winner."""
    # Check rows and columns
    for i in range(3):
        if board[i][0] == board[i][1] == board[i][2] and board[i][0] != " ":
            return board[i][0]
        if board[0][i] == board[1][i] == board[2][i] and board[0][i] != " ":
            return board[0][i]

    # Check diagonals
    if board[0][0] == board[1][1] == board[2][2] and board[0][0] != " ":
        return board[0][0]
    if board[0][2] == board[1][1] == board[2][0] and board[0][2] != " ":
        return board[0][2]

    return None

def is_draw(board):
    """Check if the game is a draw."""
    for row in board:
        if " " in row:
            return False
    return True

def tic_tac_toe():
    """Main function to play Tic-Tac-Toe."""
    board = [[" " for _ in range(3)] for _ in range(3)]
    players = ["X", "O"]
    turn = 0

    print("Welcome to Tic-Tac-Toe!")
    print("Player 1 is 'X' and Player 2 is 'O'\n")

    while True:
        print_board(board)
        current_player = players[turn % 2]
        print(f"Player {turn % 2 + 1}'s turn ({current_player}):")

        try:
            row, col = map(int, input("Enter row and column (0, 1, 2 separated by a space): ").split())
            if board[row][col] == " ":
                board[row][col] = current_player
            else:
                print("That spot is already taken! Try again.")
                continue
        except (ValueError, IndexError):
            print("Invalid input. Enter row and column numbers between 0 and 2.")
            continue

        winner = check_winner(board)
        if winner:
            print_board(board)
            print(f"Player {turn % 2 + 1} ({winner}) wins!")
            break

        if is_draw(board):
            print_board(board)
            print("It's a draw!")
            break

        turn += 1

# Run the game
tic_tac_toe()
# Out:
# Welcome to Tic-Tac-Toe!
# Player 1 is 'X' and Player 2 is 'O'
#
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player 1's turn (X):
# Enter row and column (0, 1, 2 separated by a space): 1
# Invalid input. Enter row and column numbers between 0 and 2.
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player 1's turn (X):
# Enter row and column (0, 1, 2 separated by a space): 2
# Invalid input. Enter row and column numbers between 0 and 2.
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player 1's turn (X):
# Enter row and column (0, 1, 2 separated by a space): 00
# Invalid input. Enter row and column numbers between 0 and 2.
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player 1's turn (X):
# Enter row and column (0, 1, 2 separated by a space): 0 0
# X |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Player 2's turn (O):
# Enter row and column (0, 1, 2 separated by a space): 1 0
# X |   |
# ...
